# %%
# Rerwite the scrapped walkthroughs

import os
from openai import OpenAI
from dotenv import load_dotenv

# Load environment variables
load_dotenv()

# Set up OpenAI client
client = OpenAI(api_key=os.getenv("OPENAI_API_KEY"))

def rewrite_walkthrough(input_text):
    """
    Rewrites a Pokemon game walkthrough to be more concise using GPT-3.5 Turbo.
    
    :param input_text: The original walkthrough text
    :return: The rewritten, concise walkthrough
    """
    prompt = f"""
    Rewrite the following Pokemon game walkthrough to be more concise and focused on core information.
    Remove unnecessary details and focus on key instructions and important game progress points.
    Keep the essential gameplay elements, item locations, and battle strategies.
    
    Original walkthrough:
    {input_text}
    
    Concise walkthrough:
    """

    try:
        response = client.chat.completions.create(
            model="gpt-4o-mini",
            messages=[
                {"role": "system", "content": "You are a helpful assistant that rewrites Pokemon game walkthroughs to be more concise while retaining key information."},
                {"role": "user", "content": prompt}
            ],
            max_tokens=1000,
            n=1,
            temperature=0.7,
        )
        return response.choices[0].message.content.strip()
    except Exception as e:
        print(f"Error in rewrite_walkthrough: {e}")
        return None

def get_keywords(file_path):
    """
    Extracts keywords from the third line of the file.
    
    :param file_path: Path to the walkthrough file
    :return: Extracted keywords
    """
    try:
        with open(file_path, 'r', encoding='utf-8') as file:
            lines = file.readlines()
            if len(lines) >= 3:
                return lines[2].strip().split(': ')[-1]  # Extract everything after 'Keywords: '
    except Exception as e:
        print(f"Error reading keywords from {file_path}: {e}")
    return "Keywords not found"

def process_walkthrough_files(input_directory, output_directory, game, parts):
    """
    Processes specified walkthrough files for a given game and rewrites them.
    
    :param input_directory: The base directory containing the original walkthrough files
    :param output_directory: The base directory for saving rewritten walkthroughs
    :param game: The specific game folder (e.g., "Black_and_White")
    :param parts: List of part numbers to process
    """
    input_game_directory = os.path.join(input_directory, game)
    output_game_directory = os.path.join(output_directory, game)
    
    # Create output directory if it doesn't exist
    os.makedirs(output_game_directory, exist_ok=True)
    
    for part in parts:
        filename = f"Part {part}.txt"
        input_file_path = os.path.join(input_game_directory, filename)
        
        if os.path.exists(input_file_path):
            keywords = get_keywords(input_file_path)
            print(f"Keywords for Part {part}: {keywords}")
            
            try:
                with open(input_file_path, 'r', encoding='utf-8') as file:
                    original_content = file.read()
                
                print(f"Processing {filename}...")
                rewritten_content = rewrite_walkthrough(original_content)
                
                if rewritten_content:
                    # Create a new filename with game name, part number, and keywords
                    output_filename = f"{game} - Part {part} - {keywords}.txt"
                    output_file_path = os.path.join(output_game_directory, output_filename)
                    
                    with open(output_file_path, 'w', encoding='utf-8') as file:
                        file.write(f"Game: {game}\n")
                        file.write(f"Part: {part}\n")
                        file.write(f"Keywords: {keywords}\n\n")
                        file.write(rewritten_content)
                    
                    print(f"Rewritten walkthrough saved as {output_filename}")
                else:
                    print(f"Failed to rewrite content for {filename}")
            except Exception as e:
                print(f"Error processing {filename}: {e}")
        else:
            print(f"File not found: {input_file_path}")

# # Usage
# input_walkthrough_directory = "walkthroughs"
# output_walkthrough_directory = "walkthrough_rewrites"
# game = "Black_and_White"
# parts_to_process = [1, 2, 3, 4]

# process_walkthrough_files(input_walkthrough_directory, output_walkthrough_directory, game, parts_to_process)

# %%
# Rewrite entire folder using above code

import os

def process_all_walkthroughs(input_directory, output_directory):
    """
    Process all walkthrough files for all games in the input directory.
    
    :param input_directory: Base directory containing all game walkthrough folders
    :param output_directory: Base directory for saving rewritten walkthroughs
    """
    for game_folder in os.listdir(input_directory):
        game_path = os.path.join(input_directory, game_folder)
        if os.path.isdir(game_path):
            print(f"Processing game: {game_folder}")
            
            # Get all part numbers for this game
            parts = []
            for filename in os.listdir(game_path):
                if filename.startswith("Part") and filename.endswith(".txt"):
                    part_number = filename.split()[1].split('.')[0]
                    parts.append(int(part_number))
            
            # Sort the parts in ascending order
            parts.sort()
            
            # Process all parts for this game
            process_walkthrough_files(input_directory, output_directory, game_folder, parts)
            
            print(f"Finished processing {game_folder}")

# Usage
input_walkthrough_directory = "walkthroughs"
output_walkthrough_directory = "walkthrough_rewrites"

process_all_walkthroughs(input_walkthrough_directory, output_walkthrough_directory)
# Out:
# Processing game: Black2_and_White2
# Keywords for Part 1: Introduction, Aspertia City, Route 19, Floccesy Town
# Processing Part 1.txt...
# Rewritten walkthrough saved as Black2_and_White2 - Part 1 - Introduction, Aspertia City, Route 19, Floccesy Town.txt
# Keywords for Part 2: Route 20, Floccesy Ranch, Pledge Grove, Aspertia Gym
# Processing Part 2.txt...
# Rewritten walkthrough saved as Black2_and_White2 - Part 2 - Route 20, Floccesy Ranch, Pledge Grove, Aspertia Gym.txt
# Keywords for Part 3: Virbank City, Virbank Complex, Virbank Gym, Pokéstar Studios
# Processing Part 3.txt...
# Rewritten walkthrough saved as Black2_and_White2 - Part 3 - Virbank City, Virbank Complex, Virbank Gym, Pokéstar Studios.txt
# Keywords for Part 4: Castelia City, Castelia Sewers, Castelia Gym
# Processing Part 4.txt...
# Rewritten walkthrough saved as Black2_and_White2 - Part 4 - Castelia City, Castelia Sewers, Castelia Gym.txt
# Keywords for Part 5: Route 4, Desert Resort, Relic Castle, Join Avenue
# Processing Part 5.txt...
# Rewritten walkthrough saved as Black2_and_White2 - Part 5 - Route 4, Desert Resort, Relic Castle, Join Avenue.txt
# Keywords for Part 6: Nimbasa City, Nimbasa Gym, Anville Town, Route 16, Lostlorn Forest
# Processing Part 6.txt...
# Rewritten walkthrough saved as Black2_and_White2 - Part 6 - Nimbasa City, Nimbasa Gym, Anville Town, Route 16, Lostlorn Forest.txt
# Keywords for Part 7: Route 5, Driftveil Drawbridge, Driftveil City, Driftveil Gym
# Processing Part 7.txt...
# Rewritten walkthrough saved as Black2_and_White2 - Part 7 - Route 5, Driftveil Drawbridge, Driftveil City, Driftveil Gym.txt
# Keywords for Part 8: Pokémon World Tournament, Plasma Frigate, Relic Passage
# Processing Part 8.txt...
# Rewritten walkthrough saved as Black2_and_White2 - Part 8 - Pokémon World Tournament, Plasma Frigate, Relic Passage.txt
# Keywords for Part 9: Route 6, Mistralton Cave, Chargestone Cave
# Processing Part 9.txt...
# Rewritten walkthrough saved as Black2_and_White2 - Part 9 - Route 6, Mistralton Cave, Chargestone Cave.txt
# Keywords for Part 10: Mistralton City, Route 7, Celestial Tower, Mistralton Gym
# Processing Part 10.txt...
# Rewritten walkthrough saved as Black2_and_White2 - Part 10 - Mistralton City, Route 7, Celestial Tower, Mistralton Gym.txt
# Keywords for Part 11: Lentimas Town, Strange House, Reversal Mountain, Undella Town, Undella Bay
# Processing Part 11.txt...
# Rewritten walkthrough saved as Black2_and_White2 - Part 11 - Lentimas Town, Strange House, Reversal Mountain, Undella Town, Undella Bay.txt
# Keywords for Part 12: Route 13, Lacunosa Town, Route 12, Village Bridge, Route 11
# Processing Part 12.txt...
# Rewritten walkthrough saved as Black2_and_White2 - Part 12 - Route 13, Lacunosa Town, Route 12, Village Bridge, Route 11.txt
# Keywords for Part 13: Opelucid City, Route 9, Opelucid Gym, Marine Tube, Humilau City, Humilau Gym, Route 22
# Processing Part 13.txt...
# Rewritten walkthrough saved as Black2_and_White2 - Part 13 - Opelucid City, Route 9, Opelucid Gym, Marine Tube, Humilau City, Humilau Gym, Route 22.txt
# Keywords for Part 14: Route 21, Seaside Cave, Plasma Frigate, Giant Chasm
# Processing Part 14.txt...
# Rewritten walkthrough saved as Black2_and_White2 - Part 14 - Route 21, Seaside Cave, Plasma Frigate, Giant Chasm.txt
# Keywords for Part 15: Route 23, Victory Road, The Pokémon League
# Processing Part 15.txt...
# Rewritten walkthrough saved as Black2_and_White2 - Part 15 - Route 23, Victory Road, The Pokémon League.txt
# Keywords for Part 16: Aspertia City, Floccesy Town, Cave of Being, Castelia City, Nimbasa City
# Processing Part 16.txt...
# Rewritten walkthrough saved as Black2_and_White2 - Part 16 - Aspertia City, Floccesy Town, Cave of Being, Castelia City, Nimbasa City.txt
# Keywords for Part 17: Driftveil City, Clay Tunnel, Underground Ruins, Undella Town, Abyssal Ruins
# Processing Part 17.txt...
# Rewritten walkthrough saved as Black2_and_White2 - Part 17 - Driftveil City, Clay Tunnel, Underground Ruins, Undella Town, Abyssal Ruins.txt
# Keywords for Part 18: Route 14, Abundant Shrine, Black City & White Forest, Route 15, Marvelous Bridge
# Processing Part 18.txt...
# Rewritten walkthrough saved as Black2_and_White2 - Part 18 - Route 14, Abundant Shrine, Black City & White Forest, Route 15, Marvelous Bridge.txt
# Keywords for Part 19: N's Castle, Tubeline Bridge, Route 8, Moor of Icirrus, Icirrus City, Dragonspiral Tower, Giant Chasm
# Processing Part 19.txt...
# Rewritten walkthrough saved as Black2_and_White2 - Part 19 - N's Castle, Tubeline Bridge, Route 8, Moor of Icirrus, Icirrus City, Dragonspiral Tower, Giant Chasm.txt
# Keywords for Part 20: Skyarrow Bridge, Pinwheel Forest, Nacrene City, Route 3, Wellspring Cave, Striaton City, The Dreamyard
# Processing Part 20.txt...
# Rewritten walkthrough saved as Black2_and_White2 - Part 20 - Skyarrow Bridge, Pinwheel Forest, Nacrene City, Route 3, Wellspring Cave, Striaton City, The Dreamyard.txt
# Keywords for Part 21: Route 2, Accumula Town, Route 1, Routes 17 & 18, P2 Laboratory, Nuvema Town
# Processing Part 21.txt...
# Rewritten walkthrough saved as Black2_and_White2 - Part 21 - Route 2, Accumula Town, Route 1, Routes 17 & 18, P2 Laboratory, Nuvema Town.txt
# Keywords for Part 22: Round 2
# Processing Part 22.txt...
# Rewritten walkthrough saved as Black2_and_White2 - Part 22 - Round 2.txt
# Finished processing Black2_and_White2
# Processing game: Black_and_White
# Keywords for Part 1: Introduction, Nuvema Town, Juniper's Lab, Route 1, Accumula Town
# Processing Part 1.txt...
# Rewritten walkthrough saved as Black_and_White - Part 1 - Introduction, Nuvema Town, Juniper's Lab, Route 1, Accumula Town.txt
# Keywords for Part 2: Route 2, Striaton City, The Dreamyard, Striaton Gym
# Processing Part 2.txt...
# Rewritten walkthrough saved as Black_and_White - Part 2 - Route 2, Striaton City, The Dreamyard, Striaton Gym.txt
# Keywords for Part 3: Route 3, Wellspring Cave, Nacrene City, Nacrene Gym
# Processing Part 3.txt...
# Rewritten walkthrough saved as Black_and_White - Part 3 - Route 3, Wellspring Cave, Nacrene City, Nacrene Gym.txt
# Keywords for Part 4: Pinwheel Forest, Skyarrow Bridge, Castelia City, Castelia Gym
# Processing Part 4.txt...
# Rewritten walkthrough saved as Black_and_White - Part 4 - Pinwheel Forest, Skyarrow Bridge, Castelia City, Castelia Gym.txt
# Keywords for Part 5: Route 4, Desert Resort, Relic Castle, Nimbasa City, Nimbasa Gym, Anville Town
# Processing Part 5.txt...
# Rewritten walkthrough saved as Black_and_White - Part 5 - Route 4, Desert Resort, Relic Castle, Nimbasa City, Nimbasa Gym, Anville Town.txt
# Keywords for Part 6: Route 5, Driftveil Drawbridge, Driftveil City, Cold Storage, Driftveil Gym
# Processing Part 6.txt...
# Rewritten walkthrough saved as Black_and_White - Part 6 - Route 5, Driftveil Drawbridge, Driftveil City, Cold Storage, Driftveil Gym.txt
# Keywords for Part 7: Route 6, Chargestone Cave, Mistralton City, Route 7, Celestial Tower, Mistralton Gym
# Processing Part 7.txt...
# Rewritten walkthrough saved as Black_and_White - Part 7 - Route 6, Chargestone Cave, Mistralton City, Route 7, Celestial Tower, Mistralton Gym.txt
# Keywords for Part 8: Route 17, Route 18, P2 Laboratory, Mistralton Cave, Rumination Field
# Processing Part 8.txt...
# Rewritten walkthrough saved as Black_and_White - Part 8 - Route 17, Route 18, P2 Laboratory, Mistralton Cave, Rumination Field.txt
# Keywords for Part 9: Twist Mountain, Icirrus City, Icirrus Gym, Dragonspiral Tower
# Processing Part 9.txt...
# Rewritten walkthrough saved as Black_and_White - Part 9 - Twist Mountain, Icirrus City, Icirrus Gym, Dragonspiral Tower.txt
# Keywords for Part 10: Relic Castle, Nacrene Museum, Route 8, Moor of Icirrus, Tubeline Bridge, Route 9
# Processing Part 10.txt...
# Rewritten walkthrough saved as Black_and_White - Part 10 - Relic Castle, Nacrene Museum, Route 8, Moor of Icirrus, Tubeline Bridge, Route 9.txt
# Keywords for Part 11: Opelucid City, Opelucid Gym, Route 10, Victory Road
# Processing Part 11.txt...
# Rewritten walkthrough saved as Black_and_White - Part 11 - Opelucid City, Opelucid Gym, Route 10, Victory Road.txt
# Keywords for Part 12: Elite Four, N's Castle
# Processing Part 12.txt...
# Rewritten walkthrough saved as Black_and_White - Part 12 - Elite Four, N's Castle.txt
# Keywords for Part 13: Nuvema Town, The Dreamyard, The Royal Unova, Relic Castle, Nimbasa City
# Processing Part 13.txt...
# Rewritten walkthrough saved as Black_and_White - Part 13 - Nuvema Town, The Dreamyard, The Royal Unova, Relic Castle, Nimbasa City.txt
# Keywords for Part 14: Driftveil City, Chargestone Cave, Twist Mountain, Challenger's Cave, Opelucid City
# Processing Part 14.txt...
# Rewritten walkthrough saved as Black_and_White - Part 14 - Driftveil City, Chargestone Cave, Twist Mountain, Challenger's Cave, Opelucid City.txt
# Keywords for Part 15: Champion
# Processing Part 15.txt...
# Rewritten walkthrough saved as Black_and_White - Part 15 - Champion.txt
# Keywords for Part 16: Route 11, Village Bridge, Route 12, Lacunosa Town, Route 13, Giant Chasm
# Processing Part 16.txt...
# Rewritten walkthrough saved as Black_and_White - Part 16 - Route 11, Village Bridge, Route 12, Lacunosa Town, Route 13, Giant Chasm.txt
# Keywords for Part 17: Undella Town, Undella Bay, Abyssal Ruins, Route 14, Abundant Shrine
# Processing Part 17.txt...
# Rewritten walkthrough saved as Black_and_White - Part 17 - Undella Town, Undella Bay, Abyssal Ruins, Route 14, Abundant Shrine.txt
# Keywords for Part 18: Black City and White Forest, Route 15, Poké Transfer Lab, Marvelous Bridge, Route 16, Lostlorn Forest
# Processing Part 18.txt...
# Rewritten walkthrough saved as Black_and_White - Part 18 - Black City and White Forest, Route 15, Poké Transfer Lab, Marvelous Bridge, Route 16, Lostlorn Forest.txt
# Finished processing Black_and_White
# Processing game: BrilliantDiamond_and_ShiningPearl
# Keywords for Part 1: Introduction, Twinleaf Town, Verity Lakefront, Lake Verity, Twinleaf Town, Route 201, Sandgem Town, Twinleaf Town
# Processing Part 1.txt...
# Error processing Part 1.txt: [Errno 2] No such file or directory: 'walkthrough_rewrites\\BrilliantDiamond_and_ShiningPearl\\BrilliantDiamond_and_ShiningPearl - Part 1 - Introduction, Twinleaf Town, Verity Lakefront, Lake Verity, Twinleaf Town, Route 201, Sandgem Town, Twinleaf Town.txt'
# Keywords for Part 2: Route 202, Jubilife City, Route 204, Ravaged Path, Route 203, Oreburgh Gate
# Processing Part 2.txt...
# Rewritten walkthrough saved as BrilliantDiamond_and_ShiningPearl - Part 2 - Route 202, Jubilife City, Route 204, Ravaged Path, Route 203, Oreburgh Gate.txt
# Keywords for Part 3: Oreburgh City, Route 207, Oreburgh Mine, Oreburgh Gym, Oreburgh Gate, Jubilife City, Route 204, Ravaged Path
# Processing Part 3.txt...
# Error processing Part 3.txt: [Errno 2] No such file or directory: 'walkthrough_rewrites\\BrilliantDiamond_and_ShiningPearl\\BrilliantDiamond_and_ShiningPearl - Part 3 - Oreburgh City, Route 207, Oreburgh Mine, Oreburgh Gym, Oreburgh Gate, Jubilife City, Route 204, Ravaged Path.txt'
# Keywords for Part 4: Floaroma Town, Route 205 (south), Valley Windworks, Floaroma Meadow, Valley Windworks, Route 205 (south), Eterna Forest, Route 205 (east)
# Processing Part 4.txt...
# Error processing Part 4.txt: [Errno 2] No such file or directory: 'walkthrough_rewrites\\BrilliantDiamond_and_ShiningPearl\\BrilliantDiamond_and_ShiningPearl - Part 4 - Floaroma Town, Route 205 (south), Valley Windworks, Floaroma Meadow, Valley Windworks, Route 205 (south), Eterna Forest, Route 205 (east).txt'
# Keywords for Part 5: Eterna City, Eterna Gym, Team Galactic Eterna Building, Using Cut, Route 211 (west), Mount Coronet (north)
# Processing Part 5.txt...
# Error processing Part 5.txt: [Errno 2] No such file or directory: 'walkthrough_rewrites\\BrilliantDiamond_and_ShiningPearl\\BrilliantDiamond_and_ShiningPearl - Part 5 - Eterna City, Eterna Gym, Team Galactic Eterna Building, Using Cut, Route 211 (west), Mount Coronet (north).txt'
# Keywords for Part 6: Route 206, Wayward Cave, Route 207, Oreburgh Gate, Mount Coronet (south), Route 208
# Processing Part 6.txt...
# Rewritten walkthrough saved as BrilliantDiamond_and_ShiningPearl - Part 6 - Route 206, Wayward Cave, Route 207, Oreburgh Gate, Mount Coronet (south), Route 208.txt
# Keywords for Part 7: Hearthome City, Amity Square, Route 209, Lost Tower
# Processing Part 7.txt...
# Rewritten walkthrough saved as BrilliantDiamond_and_ShiningPearl - Part 7 - Hearthome City, Amity Square, Route 209, Lost Tower.txt
# Keywords for Part 8: Solaceon Town, Solaceon Ruins, Route 210 (south)
# Processing Part 8.txt...
# Rewritten walkthrough saved as BrilliantDiamond_and_ShiningPearl - Part 8 - Solaceon Town, Solaceon Ruins, Route 210 (south).txt
# Keywords for Part 9: Route 215, Veilstone City, Veilstone Gym
# Processing Part 9.txt...
# Rewritten walkthrough saved as BrilliantDiamond_and_ShiningPearl - Part 9 - Route 215, Veilstone City, Veilstone Gym.txt
# Keywords for Part 10: Route 214, Valor Lakefront, Hotel Grand Lake
# Processing Part 10.txt...
# Rewritten walkthrough saved as BrilliantDiamond_and_ShiningPearl - Part 10 - Route 214, Valor Lakefront, Hotel Grand Lake.txt
# Keywords for Part 11: Route 213, Pastoria City, Great Marsh, Pastoria Gym, Route 213, Valor Lakefront
# Processing Part 11.txt...
# Rewritten walkthrough saved as BrilliantDiamond_and_ShiningPearl - Part 11 - Route 213, Pastoria City, Great Marsh, Pastoria Gym, Route 213, Valor Lakefront.txt
# Keywords for Part 12: Route 212, Route 210 (north), Celestic Town, Route 211 (east), Hearthome Gym
# Processing Part 12.txt...
# Rewritten walkthrough saved as BrilliantDiamond_and_ShiningPearl - Part 12 - Route 212, Route 210 (north), Celestic Town, Route 211 (east), Hearthome Gym.txt
# Keywords for Part 13: Using Surf, Fuego Ironworks, Floaroma Meadow (north), Route 219, Route 220, Route 221
# Processing Part 13.txt...
# Rewritten walkthrough saved as BrilliantDiamond_and_ShiningPearl - Part 13 - Using Surf, Fuego Ironworks, Floaroma Meadow (north), Route 219, Route 220, Route 221.txt
# Keywords for Part 14: Jubilife City, Route 218, Canalave City, Iron Island, Canalave Gym
# Processing Part 14.txt...
# Rewritten walkthrough saved as BrilliantDiamond_and_ShiningPearl - Part 14 - Jubilife City, Route 218, Canalave City, Iron Island, Canalave Gym.txt
# Keywords for Part 15: Canalave Library, Using Strength, Valor Lakefront, Lake Valor, Lake Verity
# Processing Part 15.txt...
# Rewritten walkthrough saved as BrilliantDiamond_and_ShiningPearl - Part 15 - Canalave Library, Using Strength, Valor Lakefront, Lake Valor, Lake Verity.txt
# Keywords for Part 16: Mount Coronet (north), Route 216, Route 217, Acuity Lakefront
# Processing Part 16.txt...
# Rewritten walkthrough saved as BrilliantDiamond_and_ShiningPearl - Part 16 - Mount Coronet (north), Route 216, Route 217, Acuity Lakefront.txt
# Keywords for Part 17: Snowpoint City, Snowpoint Gym, Lake Acuity, Using Rock Climb
# Processing Part 17.txt...
# Rewritten walkthrough saved as BrilliantDiamond_and_ShiningPearl - Part 17 - Snowpoint City, Snowpoint Gym, Lake Acuity, Using Rock Climb.txt
# Keywords for Part 18: Veilstone City, Galactic Warehouse, Team Galactic HQ, Mount Coronet, Spear Pillar
# Processing Part 18.txt...
# Rewritten walkthrough saved as BrilliantDiamond_and_ShiningPearl - Part 18 - Veilstone City, Galactic Warehouse, Team Galactic HQ, Mount Coronet, Spear Pillar.txt
# Keywords for Part 19: Celestic Town, Catching the Lake Guardians, Hotel Grand Lake, Route 222
# Processing Part 19.txt...
# Rewritten walkthrough saved as BrilliantDiamond_and_ShiningPearl - Part 19 - Celestic Town, Catching the Lake Guardians, Hotel Grand Lake, Route 222.txt
# Keywords for Part 20: Sunyshore City, Vista Lighthouse, Sunyshore Gym, Route 223, Victory Road
# Processing Part 20.txt...
# Rewritten walkthrough saved as BrilliantDiamond_and_ShiningPearl - Part 20 - Sunyshore City, Vista Lighthouse, Sunyshore Gym, Route 223, Victory Road.txt
# Keywords for Part 21: The Pokémon League
# Processing Part 21.txt...
# Rewritten walkthrough saved as BrilliantDiamond_and_ShiningPearl - Part 21 - The Pokémon League.txt
# Keywords for Part 22: Twinleaf Town, Sandgem Town, Poké Radar
# Processing Part 22.txt...
# Rewritten walkthrough saved as BrilliantDiamond_and_ShiningPearl - Part 22 - Twinleaf Town, Sandgem Town, Poké Radar.txt
# Keywords for Part 23: Ramanas Park, Hearthome City, Pokémon Mansion
# Processing Part 23.txt...
# Rewritten walkthrough saved as BrilliantDiamond_and_ShiningPearl - Part 23 - Ramanas Park, Hearthome City, Pokémon Mansion.txt
# Keywords for Part 24: Victory Road, Route 224, Eterna City, Eterna Forest, Old Chateau
# Processing Part 24.txt...
# Rewritten walkthrough saved as BrilliantDiamond_and_ShiningPearl - Part 24 - Victory Road, Route 224, Eterna City, Eterna Forest, Old Chateau.txt
# Keywords for Part 25: Canalave City, Fullmoon Island, Canalave City, Catching Cresselia, Iron Island
# Processing Part 25.txt...
# Rewritten walkthrough saved as BrilliantDiamond_and_ShiningPearl - Part 25 - Canalave City, Fullmoon Island, Canalave City, Catching Cresselia, Iron Island.txt
# Keywords for Part 26: Route 214, Spring Path, Sendoff Spring, Turnback Cave, Hotel Grand Lake
# Processing Part 26.txt...
# Rewritten walkthrough saved as BrilliantDiamond_and_ShiningPearl - Part 26 - Route 214, Spring Path, Sendoff Spring, Turnback Cave, Hotel Grand Lake.txt
# Keywords for Part 27: Snowpoint City, Snowpoint Temple
# Processing Part 27.txt...
# Rewritten walkthrough saved as BrilliantDiamond_and_ShiningPearl - Part 27 - Snowpoint City, Snowpoint Temple.txt
# Keywords for Part 28: Fight Area, Battle Park, Battle Tower, Route 225
# Processing Part 28.txt...
# Rewritten walkthrough saved as BrilliantDiamond_and_ShiningPearl - Part 28 - Fight Area, Battle Park, Battle Tower, Route 225.txt
# Keywords for Part 29: Survival Area, Route 226, Route 227, Stark Mountain
# Processing Part 29.txt...
# Rewritten walkthrough saved as BrilliantDiamond_and_ShiningPearl - Part 29 - Survival Area, Route 226, Route 227, Stark Mountain.txt
# Keywords for Part 30: Survival Area, Stark Mountain, Route 228
# Processing Part 30.txt...
# Rewritten walkthrough saved as BrilliantDiamond_and_ShiningPearl - Part 30 - Survival Area, Stark Mountain, Route 228.txt
# Keywords for Part 31: Route 229, Resort Area, Route 230, Fight Area
# Processing Part 31.txt...
# Rewritten walkthrough saved as BrilliantDiamond_and_ShiningPearl - Part 31 - Route 229, Resort Area, Route 230, Fight Area.txt
# Keywords for Part 32: Gym Leader Rematches, Pokémon League Rematches
# Processing Part 32.txt...
# Rewritten walkthrough saved as BrilliantDiamond_and_ShiningPearl - Part 32 - Gym Leader Rematches, Pokémon League Rematches.txt
# Finished processing BrilliantDiamond_and_ShiningPearl
# Processing game: Crystal
# Keywords for Part 1: Introduction, New Bark Town, Route 29
# Processing Part 1.txt...
# Rewritten walkthrough saved as Crystal - Part 1 - Introduction, New Bark Town, Route 29.txt
# Keywords for Part 2: Cherrygrove City, Route 30, Mr. Pokémon's House, Professor Elm's Lab
# Processing Part 2.txt...
# Rewritten walkthrough saved as Crystal - Part 2 - Cherrygrove City, Route 30, Mr. Pokémon's House, Professor Elm's Lab.txt
# Keywords for Part 3: Route 31, Violet City, Sprout Tower, Violet Gym
# Processing Part 3.txt...
# Rewritten walkthrough saved as Crystal - Part 3 - Route 31, Violet City, Sprout Tower, Violet Gym.txt
# Keywords for Part 4: Route 32, Ruins of Alph, Union Cave, Route 33
# Processing Part 4.txt...
# Rewritten walkthrough saved as Crystal - Part 4 - Route 32, Ruins of Alph, Union Cave, Route 33.txt
# Keywords for Part 5: Azalea Town, Slowpoke Well, Azalea Gym, Ilex Forest, Route 34
# Processing Part 5.txt...
# Rewritten walkthrough saved as Crystal - Part 5 - Azalea Town, Slowpoke Well, Azalea Gym, Ilex Forest, Route 34.txt
# Keywords for Part 6: Goldenrod City, Goldenrod Gym
# Processing Part 6.txt...
# Rewritten walkthrough saved as Crystal - Part 6 - Goldenrod City, Goldenrod Gym.txt
# Keywords for Part 7: Route 35, National Park, Route 36, Route 37
# Processing Part 7.txt...
# Rewritten walkthrough saved as Crystal - Part 7 - Route 35, National Park, Route 36, Route 37.txt
# Keywords for Part 8: Ecruteak City, Burned Tower, Ecruteak Gym, Route 38, Route 39
# Processing Part 8.txt...
# Rewritten walkthrough saved as Crystal - Part 8 - Ecruteak City, Burned Tower, Ecruteak Gym, Route 38, Route 39.txt
# Keywords for Part 9: Olivine City, Route 40, Route 41
# Processing Part 9.txt...
# Rewritten walkthrough saved as Crystal - Part 9 - Olivine City, Route 40, Route 41.txt
# Keywords for Part 10: Cianwood City, Cianwood Gym, Olivine Gym, Route 42, Mt. Mortar
# Processing Part 10.txt...
# Rewritten walkthrough saved as Crystal - Part 10 - Cianwood City, Cianwood Gym, Olivine Gym, Route 42, Mt. Mortar.txt
# Keywords for Part 11: Mahogany Town, Route 43, Lake of Rage, Rocket Hideout, Mahogany Gym
# Processing Part 11.txt...
# Rewritten walkthrough saved as Crystal - Part 11 - Mahogany Town, Route 43, Lake of Rage, Rocket Hideout, Mahogany Gym.txt
# Keywords for Part 12: Goldenrod Radio Tower, Goldenrod Underground, Tin Tower (1F), Route 44, Ice Path
# Processing Part 12.txt...
# Rewritten walkthrough saved as Crystal - Part 12 - Goldenrod Radio Tower, Goldenrod Underground, Tin Tower (1F), Route 44, Ice Path.txt
# Keywords for Part 13: Blackthorn City, Blackthorn Gym, Dragon's Den, Route 45, Dark Cave, Route 46
# Processing Part 13.txt...
# Rewritten walkthrough saved as Crystal - Part 13 - Blackthorn City, Blackthorn Gym, Dragon's Den, Route 45, Dark Cave, Route 46.txt
# Keywords for Part 14: Route 27, Route 26, Victory Road
# Processing Part 14.txt...
# Rewritten walkthrough saved as Crystal - Part 14 - Route 27, Route 26, Victory Road.txt
# Keywords for Part 15: Indigo Plateau
# Processing Part 15.txt...
# Rewritten walkthrough saved as Crystal - Part 15 - Indigo Plateau.txt
# Keywords for Part 16: S.S. Aqua, Vermilion City, Vermilion Gym
# Processing Part 16.txt...
# Rewritten walkthrough saved as Crystal - Part 16 - S.S. Aqua, Vermilion City, Vermilion Gym.txt
# Keywords for Part 17: Route 6, Saffron City, Saffron Gym
# Processing Part 17.txt...
# Rewritten walkthrough saved as Crystal - Part 17 - Route 6, Saffron City, Saffron Gym.txt
# Keywords for Part 18: Route 8, Lavender Town, Route 10, Rock Tunnel, Route 9, Power Plant
# Processing Part 18.txt...
# Rewritten walkthrough saved as Crystal - Part 18 - Route 8, Lavender Town, Route 10, Rock Tunnel, Route 9, Power Plant.txt
# Keywords for Part 19: Cerulean City, Route 24, Route 25, Cerulean Gym, Route 5
# Processing Part 19.txt...
# Rewritten walkthrough saved as Crystal - Part 19 - Cerulean City, Route 24, Route 25, Cerulean Gym, Route 5.txt
# Keywords for Part 20: Route 7, Celadon City, Celadon Gym
# Processing Part 20.txt...
# Rewritten walkthrough saved as Crystal - Part 20 - Route 7, Celadon City, Celadon Gym.txt
# Keywords for Part 21: Route 16, Route 17, Route 18, Fuchsia City, Fuchsia Gym
# Processing Part 21.txt...
# Rewritten walkthrough saved as Crystal - Part 21 - Route 16, Route 17, Route 18, Fuchsia City, Fuchsia Gym.txt
# Keywords for Part 22: Route 15, Route 14, Route 13, Route 12
# Processing Part 22.txt...
# Rewritten walkthrough saved as Crystal - Part 22 - Route 15, Route 14, Route 13, Route 12.txt
# Keywords for Part 23: Route 11, Diglett's Cave, Route 2, Pewter City, Pewter Gym
# Processing Part 23.txt...
# Rewritten walkthrough saved as Crystal - Part 23 - Route 11, Diglett's Cave, Route 2, Pewter City, Pewter Gym.txt
# Keywords for Part 24: Route 3, Mt. Moon, Route 4
# Processing Part 24.txt...
# Rewritten walkthrough saved as Crystal - Part 24 - Route 3, Mt. Moon, Route 4.txt
# Keywords for Part 25: Viridian City, Route 1, Pallet Town
# Processing Part 25.txt...
# Rewritten walkthrough saved as Crystal - Part 25 - Viridian City, Route 1, Pallet Town.txt
# Keywords for Part 26: Route 21, Cinnabar Island, Route 20, Cinnabar Gym, Route 19
# Processing Part 26.txt...
# Rewritten walkthrough saved as Crystal - Part 26 - Route 21, Cinnabar Island, Route 20, Cinnabar Gym, Route 19.txt
# Keywords for Part 27: Viridian Gym, Professor Oak's Lab, Route 22, Route 28
# Processing Part 27.txt...
# Rewritten walkthrough saved as Crystal - Part 27 - Viridian Gym, Professor Oak's Lab, Route 22, Route 28.txt
# Keywords for Part 28: Mt. Silver
# Processing Part 28.txt...
# Rewritten walkthrough saved as Crystal - Part 28 - Mt. Silver.txt
# Keywords for Part 29: Tying Loose Ends:Tin Tower (Revisited), Whirl Islands, Mt. Mortar (Revisited)
# Processing Part 29.txt...
# Rewritten walkthrough saved as Crystal - Part 29 - Tying Loose Ends:Tin Tower (Revisited), Whirl Islands, Mt. Mortar (Revisited).txt
# Finished processing Crystal
# Processing game: Diamond_and_Pearl
# Keywords for Part 1: Introduction, Twinleaf Town, Verity Lakefront, Lake Verity, Route 201, Sandgem Town, Back to Twinleaf Town
# Processing Part 1.txt...
# Rewritten walkthrough saved as Diamond_and_Pearl - Part 1 - Introduction, Twinleaf Town, Verity Lakefront, Lake Verity, Route 201, Sandgem Town, Back to Twinleaf Town.txt
# Keywords for Part 2: Route 202, Jubilife City, Route 204, Ravaged Path, Route 203, Oreburgh Gate, Oreburgh City
# Processing Part 2.txt...
# Rewritten walkthrough saved as Diamond_and_Pearl - Part 2 - Route 202, Jubilife City, Route 204, Ravaged Path, Route 203, Oreburgh Gate, Oreburgh City.txt
# Keywords for Part 3: Route 207, Oreburgh Mine, Oreburgh Gym, Oreburgh Gate (Basement), Jubilife City, Route 204 (South, North), Ravaged Path
# Processing Part 3.txt...
# Rewritten walkthrough saved as Diamond_and_Pearl - Part 3 - Route 207, Oreburgh Mine, Oreburgh Gym, Oreburgh Gate (Basement), Jubilife City, Route 204 (South, North), Ravaged Path.txt
# Keywords for Part 4: Floaroma Town, Route 205 (Parts 1-2), Valley Windworks, Floaroma Meadow (South), Eterna Forest
# Processing Part 4.txt...
# Rewritten walkthrough saved as Diamond_and_Pearl - Part 4 - Floaroma Town, Route 205 (Parts 1-2), Valley Windworks, Floaroma Meadow (South), Eterna Forest.txt
# Keywords for Part 5: Route 205 (Part 3), Eterna City, Route 211 (West), Mt. Coronet (Northern Area Part 1), Eterna Gym, Back to Eterna Forest, Old Chateau, Galactic Eterna Building
# Processing Part 5.txt...
# Error processing Part 5.txt: [Errno 2] No such file or directory: 'walkthrough_rewrites\\Diamond_and_Pearl\\Diamond_and_Pearl - Part 5 - Route 205 (Part 3), Eterna City, Route 211 (West), Mt. Coronet (Northern Area Part 1), Eterna Gym, Back to Eterna Forest, Old Chateau, Galactic Eterna Building.txt'
# Keywords for Part 6: Route 206, Wayward Cave (Main part), Route 207, Mt. Coronet (Southern Area Part 1), Route 208
# Processing Part 6.txt...
# Rewritten walkthrough saved as Diamond_and_Pearl - Part 6 - Route 206, Wayward Cave (Main part), Route 207, Mt. Coronet (Southern Area Part 1), Route 208.txt
# Keywords for Part 7: Hearthome City, Amity Square, Route 209
# Processing Part 7.txt...
# Rewritten walkthrough saved as Diamond_and_Pearl - Part 7 - Hearthome City, Amity Square, Route 209.txt
# Keywords for Part 8: Lost Tower, Solaceon Town, Solaceon Ruins, Route 210 (South)
# Processing Part 8.txt...
# Rewritten walkthrough saved as Diamond_and_Pearl - Part 8 - Lost Tower, Solaceon Town, Solaceon Ruins, Route 210 (South).txt
# Keywords for Part 9: Route 215, Veilstone City, Veilstone Gym, Getting back Lucas'/Dawn's PokéDex
# Processing Part 9.txt...
# Error processing Part 9.txt: [Errno 2] No such file or directory: "walkthrough_rewrites\\Diamond_and_Pearl\\Diamond_and_Pearl - Part 9 - Route 215, Veilstone City, Veilstone Gym, Getting back Lucas'/Dawn's PokéDex.txt"
# Keywords for Part 10: Route 214, Valor Lakefront, Hotel Grand Lake, Route 213, Pastoria City
# Processing Part 10.txt...
# Rewritten walkthrough saved as Diamond_and_Pearl - Part 10 - Route 214, Valor Lakefront, Hotel Grand Lake, Route 213, Pastoria City.txt
# Keywords for Part 11: Great Marsh, Pastoria Gym, Pastoria City, Route 213-Valor Lakefront
# Processing Part 11.txt...
# Rewritten walkthrough saved as Diamond_and_Pearl - Part 11 - Great Marsh, Pastoria Gym, Pastoria City, Route 213-Valor Lakefront.txt
# Keywords for Part 12: Route 212, Route 210 (North), Celestic Town, Route 211 (East), Hearthome Gym
# Processing Part 12.txt...
# Rewritten walkthrough saved as Diamond_and_Pearl - Part 12 - Route 212, Route 210 (North), Celestic Town, Route 211 (East), Hearthome Gym.txt
# Keywords for Part 13: Fuego Ironworks, Floaroma Meadow (North), Sandgem Beach and Routes 219-221
# Processing Part 13.txt...
# Rewritten walkthrough saved as Diamond_and_Pearl - Part 13 - Fuego Ironworks, Floaroma Meadow (North), Sandgem Beach and Routes 219-221.txt
# Keywords for Part 14: Jubilife City, Route 218, Canalave City, Iron Island, Canalave Gym
# Processing Part 14.txt...
# Rewritten walkthrough saved as Diamond_and_Pearl - Part 14 - Jubilife City, Route 218, Canalave City, Iron Island, Canalave Gym.txt
# Keywords for Part 15: Wayward Cave (Basement), Canalave Library, Valor Lakefront, Lake Valor, Lake Verity
# Processing Part 15.txt...
# Rewritten walkthrough saved as Diamond_and_Pearl - Part 15 - Wayward Cave (Basement), Canalave Library, Valor Lakefront, Lake Valor, Lake Verity.txt
# Keywords for Part 16: Mt. Coronet (Northern Area Part 2), Routes 216-217, Acuity Lakefront, Snowpoint City
# Processing Part 16.txt...
# Rewritten walkthrough saved as Diamond_and_Pearl - Part 16 - Mt. Coronet (Northern Area Part 2), Routes 216-217, Acuity Lakefront, Snowpoint City.txt
# Keywords for Part 17: Snowpoint Gym, Lake Acuity, Veilstone City, Galactic HQ, Galactic Warehouse, Raiding Galactic HQ (Part 1)
# Processing Part 17.txt...
# Rewritten walkthrough saved as Diamond_and_Pearl - Part 17 - Snowpoint Gym, Lake Acuity, Veilstone City, Galactic HQ, Galactic Warehouse, Raiding Galactic HQ (Part 1).txt
# Keywords for Part 18: Raiding Galactic HQ (Part 2), Mt. Coronet (Southern Area Part 2, Mountainside and Upper Caverns), Spear Pillar
# Processing Part 18.txt...
# Rewritten walkthrough saved as Diamond_and_Pearl - Part 18 - Raiding Galactic HQ (Part 2), Mt. Coronet (Southern Area Part 2, Mountainside and Upper Caverns), Spear Pillar.txt
# Keywords for Part 19: Team Galactic's final showdown, Catching Dialga/Palkia, back in Mt. Coronet
# Processing Part 19.txt...
# Error processing Part 19.txt: [Errno 2] No such file or directory: "walkthrough_rewrites\\Diamond_and_Pearl\\Diamond_and_Pearl - Part 19 - Team Galactic's final showdown, Catching Dialga/Palkia, back in Mt. Coronet.txt"
# Keywords for Part 20: Catching the Lake Guardians, Hotel Grand Lake, Route 222, Sunyshore City, Vista Lighthouse
# Processing Part 20.txt...
# Rewritten walkthrough saved as Diamond_and_Pearl - Part 20 - Catching the Lake Guardians, Hotel Grand Lake, Route 222, Sunyshore City, Vista Lighthouse.txt
# Keywords for Part 21: Sunyshore Gym, Route 223, Pokémon League (Victory Road Entrance)
# Processing Part 21.txt...
# Rewritten walkthrough saved as Diamond_and_Pearl - Part 21 - Sunyshore Gym, Route 223, Pokémon League (Victory Road Entrance).txt
# Keywords for Part 22: Victory Road, Pokémon League (Main Building), Final Rival battle
# Processing Part 22.txt...
# Rewritten walkthrough saved as Diamond_and_Pearl - Part 22 - Victory Road, Pokémon League (Main Building), Final Rival battle.txt
# Keywords for Part 23: Final Preparation, VS Elite Four, VS Champion, Hall Of Fame
# Processing Part 23.txt...
# Rewritten walkthrough saved as Diamond_and_Pearl - Part 23 - Final Preparation, VS Elite Four, VS Champion, Hall Of Fame.txt
# Keywords for Part 24: Twinleaf Town, Sandgem Town, Pokemon Research Lab — Upgrading Pokédex, Pokemon Swarm
# Processing Part 24.txt...
# Rewritten walkthrough saved as Diamond_and_Pearl - Part 24 - Twinleaf Town, Sandgem Town, Pokemon Research Lab — Upgrading Pokédex, Pokemon Swarm.txt
# Keywords for Part 25: Poké Radar, Pal Park, Dual-slot, Hearthome City, Pokemon Mansion, Pokemon League
# Processing Part 25.txt...
# Rewritten walkthrough saved as Diamond_and_Pearl - Part 25 - Poké Radar, Pal Park, Dual-slot, Hearthome City, Pokemon Mansion, Pokemon League.txt
# Keywords for Part 26: Sinnoh Victory Road, Route 224, Eterna City, Eterna Forest, Old Chateau, Catching Rotom
# Processing Part 26.txt...
# Rewritten walkthrough saved as Diamond_and_Pearl - Part 26 - Sinnoh Victory Road, Route 224, Eterna City, Eterna Forest, Old Chateau, Catching Rotom.txt
# Keywords for Part 27: Canalave City, Fullmoon Island, Back to Canalave City, Catching Cresselia, Iron Island
# Processing Part 27.txt...
# Rewritten walkthrough saved as Diamond_and_Pearl - Part 27 - Canalave City, Fullmoon Island, Back to Canalave City, Catching Cresselia, Iron Island.txt
# Keywords for Part 28: Route 214, Spring Path, Sendoff Spring, Turnback Cave, Catching Giratina, Hotel Grand Lake — Collecting Diploma
# Processing Part 28.txt...
# Rewritten walkthrough saved as Diamond_and_Pearl - Part 28 - Route 214, Spring Path, Sendoff Spring, Turnback Cave, Catching Giratina, Hotel Grand Lake — Collecting Diploma.txt
# Keywords for Part 29: Snowpoint City, Snowpoint Temple, Catching Regigigas, Heading towards the Battle Zone
# Processing Part 29.txt...
# Rewritten walkthrough saved as Diamond_and_Pearl - Part 29 - Snowpoint City, Snowpoint Temple, Catching Regigigas, Heading towards the Battle Zone.txt
# Keywords for Part 30: Fight Area, Battle Park, Battle Tower, Route 225
# Processing Part 30.txt...
# Rewritten walkthrough saved as Diamond_and_Pearl - Part 30 - Fight Area, Battle Park, Battle Tower, Route 225.txt
# Keywords for Part 31: Survival Area, Routes 226-227, Stark Mountain
# Processing Part 31.txt...
# Rewritten walkthrough saved as Diamond_and_Pearl - Part 31 - Survival Area, Routes 226-227, Stark Mountain.txt
# Keywords for Part 32: Back in Survival Area, Back to Stark Mountain, Catching Heatran, Route 228
# Processing Part 32.txt...
# Rewritten walkthrough saved as Diamond_and_Pearl - Part 32 - Back in Survival Area, Back to Stark Mountain, Catching Heatran, Route 228.txt
# Keywords for Part 33: Route 229, Resort Area, Route 230, Back in Fight Area, Rival rematch
# Processing Part 33.txt...
# Rewritten walkthrough saved as Diamond_and_Pearl - Part 33 - Route 229, Resort Area, Route 230, Back in Fight Area, Rival rematch.txt
# Finished processing Diamond_and_Pearl
# Processing game: Emerald
# Keywords for Part 1: Introduction, Littleroot Town, Route 101, Oldale Town, Route 103, Route 102, Petalburg City
# Processing Part 1.txt...
# Rewritten walkthrough saved as Emerald - Part 1 - Introduction, Littleroot Town, Route 101, Oldale Town, Route 103, Route 102, Petalburg City.txt
# Keywords for Part 2: Route 104, Petalburg Woods, Rustboro City, Rustboro Gym, Route 116, Rusturf Tunnel
# Processing Part 2.txt...
# Rewritten walkthrough saved as Emerald - Part 2 - Route 104, Petalburg Woods, Rustboro City, Rustboro Gym, Route 116, Rusturf Tunnel.txt
# Keywords for Part 3: Route 105, Route 106, Dewford Town, Dewford Gym, Granite Cave, Route 107, Route 108, Route 109
# Processing Part 3.txt...
# Rewritten walkthrough saved as Emerald - Part 3 - Route 105, Route 106, Dewford Town, Dewford Gym, Granite Cave, Route 107, Route 108, Route 109.txt
# Keywords for Part 4: Slateport City, Oceanic Museum, Route 110, Trick House
# Processing Part 4.txt...
# Rewritten walkthrough saved as Emerald - Part 4 - Slateport City, Oceanic Museum, Route 110, Trick House.txt
# Keywords for Part 5: Mauville City, Mauville Gym, Route 117, Verdanturf Town, Rusturf Tunnel (Revisited)
# Processing Part 5.txt...
# Rewritten walkthrough saved as Emerald - Part 5 - Mauville City, Mauville Gym, Route 117, Verdanturf Town, Rusturf Tunnel (Revisited).txt
# Keywords for Part 6: Route 111 (South), Route 112 (South), Fiery Path, Route 112 (North), Route 111 (North), Route 113, Fallarbor Town, Route 114
# Processing Part 6.txt...
# Rewritten walkthrough saved as Emerald - Part 6 - Route 111 (South), Route 112 (South), Fiery Path, Route 112 (North), Route 111 (North), Route 113, Fallarbor Town, Route 114.txt
# Keywords for Part 7: Meteor Falls, Route 115, Mt. Chimney, Jagged Pass, Lavaridge Town, Lavaridge Gym
# Processing Part 7.txt...
# Rewritten walkthrough saved as Emerald - Part 7 - Meteor Falls, Route 115, Mt. Chimney, Jagged Pass, Lavaridge Town, Lavaridge Gym.txt
# Keywords for Part 8: Route 111 (Desert), Mirage Tower, Petalburg Gym, Route 115, Route 105, Route 107, Route 108
# Processing Part 8.txt...
# Rewritten walkthrough saved as Emerald - Part 8 - Route 111 (Desert), Mirage Tower, Petalburg Gym, Route 115, Route 105, Route 107, Route 108.txt
# Keywords for Part 9: Abandoned Ship, New Mauville, Route 118
# Processing Part 9.txt...
# Rewritten walkthrough saved as Emerald - Part 9 - Abandoned Ship, New Mauville, Route 118.txt
# Keywords for Part 10: Route 119, Weather Institute, Fortree City, Route 120
# Processing Part 10.txt...
# Rewritten walkthrough saved as Emerald - Part 10 - Route 119, Weather Institute, Fortree City, Route 120.txt
# Keywords for Part 11: Fortree Gym, Route 121, Safari Zone, Route 122
# Processing Part 11.txt...
# Rewritten walkthrough saved as Emerald - Part 11 - Fortree Gym, Route 121, Safari Zone, Route 122.txt
# Keywords for Part 12: Mt. Pyre, Route 123, Jagged Pass, Team Magma Hideout
# Processing Part 12.txt...
# Rewritten walkthrough saved as Emerald - Part 12 - Mt. Pyre, Route 123, Jagged Pass, Team Magma Hideout.txt
# Keywords for Part 13: Slateport City, Lilycove City, Team Aqua Hideout
# Processing Part 13.txt...
# Rewritten walkthrough saved as Emerald - Part 13 - Slateport City, Lilycove City, Team Aqua Hideout.txt
# Keywords for Part 14: Route 124, Mossdeep City, Space Center, Route 125
# Processing Part 14.txt...
# Rewritten walkthrough saved as Emerald - Part 14 - Route 124, Mossdeep City, Space Center, Route 125.txt
# Keywords for Part 15: Shoal Cave, Route 127, Route 128, Seafloor Cavern
# Processing Part 15.txt...
# Rewritten walkthrough saved as Emerald - Part 15 - Shoal Cave, Route 127, Route 128, Seafloor Cavern.txt
# Keywords for Part 16: Route 126, Sootopolis City, Cave of Origin, Route 129, Route 130, Route 131, Pacifidlog Town
# Processing Part 16.txt...
# Rewritten walkthrough saved as Emerald - Part 16 - Route 126, Sootopolis City, Cave of Origin, Route 129, Route 130, Route 131, Pacifidlog Town.txt
# Keywords for Part 17: Routes 132, 133, and 134, Desert Ruins, Island Cave, Ancient Tomb, Sky Pillar, Sootopolis City
# Processing Part 17.txt...
# Rewritten walkthrough saved as Emerald - Part 17 - Routes 132, 133, and 134, Desert Ruins, Island Cave, Ancient Tomb, Sky Pillar, Sootopolis City.txt
# Keywords for Part 18: Sky Pillar, Ever Grande City, Victory Road
# Processing Part 18.txt...
# Rewritten walkthrough saved as Emerald - Part 18 - Sky Pillar, Ever Grande City, Victory Road.txt
# Keywords for Part 19: The Pokémon League
# Processing Part 19.txt...
# Rewritten walkthrough saved as Emerald - Part 19 - The Pokémon League.txt
# Keywords for Part 20: Littleroot Town, Safari Zone, Altering Cave, Desert Underpass, Terra Cave, Marine Cave, Meteor Falls, Trainer Hill
# Processing Part 20.txt...
# Rewritten walkthrough saved as Emerald - Part 20 - Littleroot Town, Safari Zone, Altering Cave, Desert Underpass, Terra Cave, Marine Cave, Meteor Falls, Trainer Hill.txt
# Keywords for Part 21: S.S. Tidal, Battle Frontier
# Processing Part 21.txt...
# Rewritten walkthrough saved as Emerald - Part 21 - S.S. Tidal, Battle Frontier.txt
# Finished processing Emerald
# Processing game: FireRed_and_LeafGreen
# Keywords for Part 1: Introduction, Pallet Town
# Processing Part 1.txt...
# Rewritten walkthrough saved as FireRed_and_LeafGreen - Part 1 - Introduction, Pallet Town.txt
# Keywords for Part 2: Route 1, Viridian City, Pallet Town (Revisited), Route 2 (West)
# Processing Part 2.txt...
# Rewritten walkthrough saved as FireRed_and_LeafGreen - Part 2 - Route 1, Viridian City, Pallet Town (Revisited), Route 2 (West).txt
# Keywords for Part 3: Viridian Forest, Pewter City, Pewter Gym
# Processing Part 3.txt...
# Rewritten walkthrough saved as FireRed_and_LeafGreen - Part 3 - Viridian Forest, Pewter City, Pewter Gym.txt
# Keywords for Part 4: Route 3, Mt. Moon, Route 4
# Processing Part 4.txt...
# Rewritten walkthrough saved as FireRed_and_LeafGreen - Part 4 - Route 3, Mt. Moon, Route 4.txt
# Keywords for Part 5: Cerulean City, Cerulean Gym, Route 24, Route 25, Route 5, Underground Path (Routes 5-6)
# Processing Part 5.txt...
# Rewritten walkthrough saved as FireRed_and_LeafGreen - Part 5 - Cerulean City, Cerulean Gym, Route 24, Route 25, Route 5, Underground Path (Routes 5-6).txt
# Keywords for Part 6: Route 6, Vermilion City, S.S. Anne, Vermilion Gym
# Processing Part 6.txt...
# Rewritten walkthrough saved as FireRed_and_LeafGreen - Part 6 - Route 6, Vermilion City, S.S. Anne, Vermilion Gym.txt
# Keywords for Part 7: Route 11, Diglett's Cave, Route 2 (East), Pewter Museum of Science, Route 9, Route 10 (North)
# Processing Part 7.txt...
# Rewritten walkthrough saved as FireRed_and_LeafGreen - Part 7 - Route 11, Diglett's Cave, Route 2 (East), Pewter Museum of Science, Route 9, Route 10 (North).txt
# Keywords for Part 8: Rock Tunnel, Route 10 (South), Lavender Town, Route 8, Underground Path (Routes 7-8), Route 7
# Processing Part 8.txt...
# Rewritten walkthrough saved as FireRed_and_LeafGreen - Part 8 - Rock Tunnel, Route 10 (South), Lavender Town, Route 8, Underground Path (Routes 7-8), Route 7.txt
# Keywords for Part 9: Celadon City, Celadon Gym, Rocket Hideout, Pokémon Tower
# Processing Part 9.txt...
# Rewritten walkthrough saved as FireRed_and_LeafGreen - Part 9 - Celadon City, Celadon Gym, Rocket Hideout, Pokémon Tower.txt
# Keywords for Part 10: Saffron City, Silph Co., Saffron Gym
# Processing Part 10.txt...
# Rewritten walkthrough saved as FireRed_and_LeafGreen - Part 10 - Saffron City, Silph Co., Saffron Gym.txt
# Keywords for Part 11: Route 16, Route 17, Route 18, Fuchsia City, Fuchsia Gym, Safari Zone
# Processing Part 11.txt...
# Rewritten walkthrough saved as FireRed_and_LeafGreen - Part 11 - Route 16, Route 17, Route 18, Fuchsia City, Fuchsia Gym, Safari Zone.txt
# Keywords for Part 12: Route 12, Route 13, Route 14, Route 15, Route 19, Route 20 (East), Seafoam Islands, Route 20 (West)
# Processing Part 12.txt...
# Rewritten walkthrough saved as FireRed_and_LeafGreen - Part 12 - Route 12, Route 13, Route 14, Route 15, Route 19, Route 20 (East), Seafoam Islands, Route 20 (West).txt
# Keywords for Part 13: Cinnabar Island, Pokémon Lab, Pokémon Mansion, Cinnabar Gym
# Processing Part 13.txt...
# Rewritten walkthrough saved as FireRed_and_LeafGreen - Part 13 - Cinnabar Island, Pokémon Lab, Pokémon Mansion, Cinnabar Gym.txt
# Keywords for Part 14: Sevii Islands, Part I:One Island, Two Island, Three Island
# Processing Part 14.txt...
# Rewritten walkthrough saved as FireRed_and_LeafGreen - Part 14 - Sevii Islands, Part I:One Island, Two Island, Three Island.txt
# Keywords for Part 15: Route 21, Power Plant, Viridian Gym
# Processing Part 15.txt...
# Rewritten walkthrough saved as FireRed_and_LeafGreen - Part 15 - Route 21, Power Plant, Viridian Gym.txt
# Keywords for Part 16: Route 22, Route 23, Victory Road
# Processing Part 16.txt...
# Rewritten walkthrough saved as FireRed_and_LeafGreen - Part 16 - Route 22, Route 23, Victory Road.txt
# Keywords for Part 17: Indigo Plateau
# Processing Part 17.txt...
# Rewritten walkthrough saved as FireRed_and_LeafGreen - Part 17 - Indigo Plateau.txt
# Keywords for Part 18: Sevii Islands, Part II:Four Island, Six Island
# Processing Part 18.txt...
# Rewritten walkthrough saved as FireRed_and_LeafGreen - Part 18 - Sevii Islands, Part II:Four Island, Six Island.txt
# Keywords for Part 19: Sevii Islands, Part III:Five Island, Seven Island
# Processing Part 19.txt...
# Rewritten walkthrough saved as FireRed_and_LeafGreen - Part 19 - Sevii Islands, Part III:Five Island, Seven Island.txt
# Keywords for Part 20: Round 2
# Processing Part 20.txt...
# Rewritten walkthrough saved as FireRed_and_LeafGreen - Part 20 - Round 2.txt
# Finished processing FireRed_and_LeafGreen
# Processing game: Gold_and_Silver
# Keywords for Part 1: Introduction, New Bark Town, Route 29
# Processing Part 1.txt...
# Rewritten walkthrough saved as Gold_and_Silver - Part 1 - Introduction, New Bark Town, Route 29.txt
# Keywords for Part 2: Cherrygrove City, Route 30, Mr. Pokémon's House, Professor Elm's Lab
# Processing Part 2.txt...
# Rewritten walkthrough saved as Gold_and_Silver - Part 2 - Cherrygrove City, Route 30, Mr. Pokémon's House, Professor Elm's Lab.txt
# Keywords for Part 3: Route 31, Violet City, Sprout Tower, Violet Gym
# Processing Part 3.txt...
# Rewritten walkthrough saved as Gold_and_Silver - Part 3 - Route 31, Violet City, Sprout Tower, Violet Gym.txt
# Keywords for Part 4: Route 32, Ruins of Alph, Union Cave, Route 33
# Processing Part 4.txt...
# Rewritten walkthrough saved as Gold_and_Silver - Part 4 - Route 32, Ruins of Alph, Union Cave, Route 33.txt
# Keywords for Part 5: Azalea Town, Slowpoke Well, Azalea Gym, Ilex Forest, Route 34
# Processing Part 5.txt...
# Rewritten walkthrough saved as Gold_and_Silver - Part 5 - Azalea Town, Slowpoke Well, Azalea Gym, Ilex Forest, Route 34.txt
# Keywords for Part 6: Goldenrod City, Goldenrod Gym
# Processing Part 6.txt...
# Rewritten walkthrough saved as Gold_and_Silver - Part 6 - Goldenrod City, Goldenrod Gym.txt
# Keywords for Part 7: Route 35, National Park, Route 36, Route 37
# Processing Part 7.txt...
# Rewritten walkthrough saved as Gold_and_Silver - Part 7 - Route 35, National Park, Route 36, Route 37.txt
# Keywords for Part 8: Ecruteak City, Burned Tower, Ecruteak Gym, Route 38, Route 39
# Processing Part 8.txt...
# Rewritten walkthrough saved as Gold_and_Silver - Part 8 - Ecruteak City, Burned Tower, Ecruteak Gym, Route 38, Route 39.txt
# Keywords for Part 9: Olivine City, Route 40, Route 41
# Processing Part 9.txt...
# Rewritten walkthrough saved as Gold_and_Silver - Part 9 - Olivine City, Route 40, Route 41.txt
# Keywords for Part 10: Cianwood City, Cianwood Gym, Olivine Gym, Route 42, Mt. Mortar
# Processing Part 10.txt...
# Rewritten walkthrough saved as Gold_and_Silver - Part 10 - Cianwood City, Cianwood Gym, Olivine Gym, Route 42, Mt. Mortar.txt
# Keywords for Part 11: Mahogany Town, Route 43, Lake of Rage, Rocket Hideout, Mahogany Gym
# Processing Part 11.txt...
# Rewritten walkthrough saved as Gold_and_Silver - Part 11 - Mahogany Town, Route 43, Lake of Rage, Rocket Hideout, Mahogany Gym.txt
# Keywords for Part 12: Goldenrod Radio Tower, Goldenrod Underground, Route 44, Ice Path
# Processing Part 12.txt...
# Rewritten walkthrough saved as Gold_and_Silver - Part 12 - Goldenrod Radio Tower, Goldenrod Underground, Route 44, Ice Path.txt
# Keywords for Part 13: Blackthorn City, Blackthorn Gym, Dragon's Den, Route 45, Dark Cave, Route 46
# Processing Part 13.txt...
# Rewritten walkthrough saved as Gold_and_Silver - Part 13 - Blackthorn City, Blackthorn Gym, Dragon's Den, Route 45, Dark Cave, Route 46.txt
# Keywords for Part 14: Route 27, Route 26, Victory Road
# Processing Part 14.txt...
# Rewritten walkthrough saved as Gold_and_Silver - Part 14 - Route 27, Route 26, Victory Road.txt
# Keywords for Part 15: Indigo Plateau
# Processing Part 15.txt...
# Rewritten walkthrough saved as Gold_and_Silver - Part 15 - Indigo Plateau.txt
# Keywords for Part 16: S.S. Aqua, Vermilion City, Vermilion Gym
# Processing Part 16.txt...
# Rewritten walkthrough saved as Gold_and_Silver - Part 16 - S.S. Aqua, Vermilion City, Vermilion Gym.txt
# Keywords for Part 17: Route 6, Saffron City, Saffron Gym
# Processing Part 17.txt...
# Rewritten walkthrough saved as Gold_and_Silver - Part 17 - Route 6, Saffron City, Saffron Gym.txt
# Keywords for Part 18: Route 8, Lavender Town, Route 10, Rock Tunnel, Route 9, Power Plant
# Processing Part 18.txt...
# Rewritten walkthrough saved as Gold_and_Silver - Part 18 - Route 8, Lavender Town, Route 10, Rock Tunnel, Route 9, Power Plant.txt
# Keywords for Part 19: Cerulean City, Route 24, Route 25, Cerulean Gym, Route 5
# Processing Part 19.txt...
# Rewritten walkthrough saved as Gold_and_Silver - Part 19 - Cerulean City, Route 24, Route 25, Cerulean Gym, Route 5.txt
# Keywords for Part 20: Route 7, Celadon City, Celadon Gym
# Processing Part 20.txt...
# Rewritten walkthrough saved as Gold_and_Silver - Part 20 - Route 7, Celadon City, Celadon Gym.txt
# Keywords for Part 21: Route 16, Route 17, Route 18, Fuchsia City, Fuchsia Gym
# Processing Part 21.txt...
# Rewritten walkthrough saved as Gold_and_Silver - Part 21 - Route 16, Route 17, Route 18, Fuchsia City, Fuchsia Gym.txt
# Keywords for Part 22: Route 15, Route 14, Route 13, Route 12
# Processing Part 22.txt...
# ...
# Keywords for Part 29: Tracking the Ultra Beasts:UB-03 Lighting, UB-04 BladeS/ BlasterM, Obtaining the Key Stone
# Processing Part 29.txt...
# Error processing Part 29.txt: [Errno 22] Invalid argument: 'walkthrough_rewrites\\Sun_and_Moon\\Sun_and_Moon - Part 29 - Tracking the Ultra Beasts:UB-03 Lighting, UB-04 BladeS/ BlasterM, Obtaining the Key Stone.txt'
# Keywords for Part 30: Tracking the Ultra Beasts:Poni Grove, Poni Plains, Poni Meadow, Resolution Cave, UB-05 Glutton, Ten Carat Hill (Farthest Hollow)
# Processing Part 30.txt...
# Rewritten walkthrough saved as Sun_and_Moon - Part 30 - Tracking the Ultra Beasts:Poni Grove, Poni Plains, Poni Meadow, Resolution Cave, UB-05 Glutton, Ten Carat Hill (Farthest Hollow).txt
# Keywords for Part 31: Tying Loose Ends:Melemele Sea, Seaward Cave, Kala'e Bay, Lake of the MooneS/ Lake of the SunneM
# Processing Part 31.txt...
# Error processing Part 31.txt: [Errno 22] Invalid argument: "walkthrough_rewrites\\Sun_and_Moon\\Sun_and_Moon - Part 31 - Tying Loose Ends:Melemele Sea, Seaward Cave, Kala'e Bay, Lake of the MooneS/ Lake of the SunneM.txt"
# Keywords for Part 32: Round 2
# Processing Part 32.txt...
# Rewritten walkthrough saved as Sun_and_Moon - Part 32 - Round 2.txt
# Finished processing Sun_and_Moon
# Processing game: Sword_and_Shield
# Finished processing Sword_and_Shield
# Processing game: UltraSun_and_UltraMoon
# Keywords for Part 1: Introduction, Route 1 (Hau'oli Outskirts), Iki Town, Mahalo Trail
# Processing Part 1.txt...
# Rewritten walkthrough saved as UltraSun_and_UltraMoon - Part 1 - Introduction, Route 1 (Hau'oli Outskirts), Iki Town, Mahalo Trail.txt
# Keywords for Part 2: Route 1, Iki Town Festival, Professor Kukui's Lab, Trainers' School
# Processing Part 2.txt...
# Rewritten walkthrough saved as UltraSun_and_UltraMoon - Part 2 - Route 1, Iki Town Festival, Professor Kukui's Lab, Trainers' School.txt
# Keywords for Part 3: Hau'oli City
# Processing Part 3.txt...
# Rewritten walkthrough saved as UltraSun_and_UltraMoon - Part 3 - Hau'oli City.txt
# Keywords for Part 4: Verdant Cavern
# Processing Part 4.txt...
# Rewritten walkthrough saved as UltraSun_and_UltraMoon - Part 4 - Verdant Cavern.txt
# Keywords for Part 5: Route 3, Melemele Meadow, Seaward Cave, Kala'e Bay
# Processing Part 5.txt...
# Rewritten walkthrough saved as UltraSun_and_UltraMoon - Part 5 - Route 3, Melemele Meadow, Seaward Cave, Kala'e Bay.txt
# Keywords for Part 6: Melemele Grand Trial, Ten Carat Hill, Hau'oli City (Shopping Mall)
# Processing Part 6.txt...
# Rewritten walkthrough saved as UltraSun_and_UltraMoon - Part 6 - Melemele Grand Trial, Ten Carat Hill, Hau'oli City (Shopping Mall).txt
# Keywords for Part 7: Heahea City, Heahea Beach, Route 4, Paniola Town, Paniola Ranch, Pokémon Nursery
# Processing Part 7.txt...
# Rewritten walkthrough saved as UltraSun_and_UltraMoon - Part 7 - Heahea City, Heahea Beach, Route 4, Paniola Town, Paniola Ranch, Pokémon Nursery.txt
# Keywords for Part 8: Brooklet Hill, Route 6
# Processing Part 8.txt...
# Rewritten walkthrough saved as UltraSun_and_UltraMoon - Part 8 - Brooklet Hill, Route 6.txt
# Keywords for Part 9: Wela Volcano Park
# Processing Part 9.txt...
# Rewritten walkthrough saved as UltraSun_and_UltraMoon - Part 9 - Wela Volcano Park.txt
# Keywords for Part 10: Lush Jungle, Route 5 (North)
# Processing Part 10.txt...
# Rewritten walkthrough saved as UltraSun_and_UltraMoon - Part 10 - Lush Jungle, Route 5 (North).txt
# Keywords for Part 11: Dimensional Research Lab, Diglett's Tunnel, Route 9, Konikoni City
# Processing Part 11.txt...
# Rewritten walkthrough saved as UltraSun_and_UltraMoon - Part 11 - Dimensional Research Lab, Diglett's Tunnel, Route 9, Konikoni City.txt
# Keywords for Part 12: Memorial Hill, Akala Outskirts, Ruins of Life, Akala Grand Trial, Hano Grand Resort, Hano Beach
# Processing Part 12.txt...
# Rewritten walkthrough saved as UltraSun_and_UltraMoon - Part 12 - Memorial Hill, Akala Outskirts, Ruins of Life, Akala Grand Trial, Hano Grand Resort, Hano Beach.txt
# Keywords for Part 13: Docks, Conservation Area
# Processing Part 13.txt...
# Rewritten walkthrough saved as UltraSun_and_UltraMoon - Part 13 - Docks, Conservation Area.txt
# Keywords for Part 14: Malie City, Malie Garden, Outer Cape
# Processing Part 14.txt...
# Rewritten walkthrough saved as UltraSun_and_UltraMoon - Part 14 - Malie City, Malie Garden, Outer Cape.txt
# Keywords for Part 15: Hokulani Observatory
# Processing Part 15.txt...
# Rewritten walkthrough saved as UltraSun_and_UltraMoon - Part 15 - Hokulani Observatory.txt
# Keywords for Part 16: Route 11, Route 12, Blush Mountain, Ula'ula Beach, Route 13
# Processing Part 16.txt...
# Rewritten walkthrough saved as UltraSun_and_UltraMoon - Part 16 - Route 11, Route 12, Blush Mountain, Ula'ula Beach, Route 13.txt
# Keywords for Part 17: Abandoned Megamart
# Processing Part 17.txt...
# Rewritten walkthrough saved as UltraSun_and_UltraMoon - Part 17 - Abandoned Megamart.txt
# Keywords for Part 18: Route 15, Route 16, Ula'ula Meadow, Route 17
# Processing Part 18.txt...
# Rewritten walkthrough saved as UltraSun_and_UltraMoon - Part 18 - Route 15, Route 16, Ula'ula Meadow, Route 17.txt
# Keywords for Part 19: Po Town, Shady House, Ula'ula Grand Trial
# Processing Part 19.txt...
# Rewritten walkthrough saved as UltraSun_and_UltraMoon - Part 19 - Po Town, Shady House, Ula'ula Grand Trial.txt
# Keywords for Part 20: Secret Labs, Lusamine's Mansion
# Processing Part 20.txt...
# Rewritten walkthrough saved as UltraSun_and_UltraMoon - Part 20 - Secret Labs, Lusamine's Mansion.txt
# Keywords for Part 21: Seafolk Village, Poni Wilds, Poni Beach, Ancient Poni Path
# Processing Part 21.txt...
# Rewritten walkthrough saved as UltraSun_and_UltraMoon - Part 21 - Seafolk Village, Poni Wilds, Poni Beach, Ancient Poni Path.txt
# Keywords for Part 22: Poni Breaker Coast, Ruins of Hope, Exeggutor Island
# Processing Part 22.txt...
# Rewritten walkthrough saved as UltraSun_and_UltraMoon - Part 22 - Poni Breaker Coast, Ruins of Hope, Exeggutor Island.txt
# Keywords for Part 23: The Captainless Trial
# Processing Part 23.txt...
# Rewritten walkthrough saved as UltraSun_and_UltraMoon - Part 23 - The Captainless Trial.txt
# Keywords for Part 24: Altar of the SunneUS/ Altar of the MooneUM, Ultra Megalopolis, Megalo Tower
# Processing Part 24.txt...
# Error processing Part 24.txt: [Errno 2] No such file or directory: 'walkthrough_rewrites\\UltraSun_and_UltraMoon\\UltraSun_and_UltraMoon - Part 24 - Altar of the SunneUS/ Altar of the MooneUM, Ultra Megalopolis, Megalo Tower.txt'
# Keywords for Part 25: Seafolk Village (Revisited), Mina's Trial, Exeggutor Island (Revisited), Poni Grand Trial
# Processing Part 25.txt...
# Rewritten walkthrough saved as UltraSun_and_UltraMoon - Part 25 - Seafolk Village (Revisited), Mina's Trial, Exeggutor Island (Revisited), Poni Grand Trial.txt
# Keywords for Part 26: Mount Lanakila
# Processing Part 26.txt...
# Rewritten walkthrough saved as UltraSun_and_UltraMoon - Part 26 - Mount Lanakila.txt
# Keywords for Part 27: The Pokémon League
# Processing Part 27.txt...
# Rewritten walkthrough saved as UltraSun_and_UltraMoon - Part 27 - The Pokémon League.txt
# Keywords for Part 28: Guardians of Alola:Ruins of Conflict, Ruins of Life, Haina Desert & Ruins of Abundance, Ruins of Hope
# Processing Part 28.txt...
# Rewritten walkthrough saved as UltraSun_and_UltraMoon - Part 28 - Guardians of Alola:Ruins of Conflict, Ruins of Life, Haina Desert & Ruins of Abundance, Ruins of Hope.txt
# Keywords for Part 29: Ultra Warp Ride
# Processing Part 29.txt...
# Rewritten walkthrough saved as UltraSun_and_UltraMoon - Part 29 - Ultra Warp Ride.txt
# Keywords for Part 30: Tracking the Ultra Beasts:Poni Grove, UB BurstUS/ UB AssemblyUM, Ten Carat Hill (Farthest Hollow)
# Processing Part 30.txt...
# Error processing Part 30.txt: [Errno 22] Invalid argument: 'walkthrough_rewrites\\UltraSun_and_UltraMoon\\UltraSun_and_UltraMoon - Part 30 - Tracking the Ultra Beasts:Poni Grove, UB BurstUS/ UB AssemblyUM, Ten Carat Hill (Farthest Hollow).txt'
# Keywords for Part 31: Tying Loose Ends:Melemele Sea, Seaward Cave, Kala'e Bay, Lake of the MooneUS/ Lake of the SunneUM
# Processing Part 31.txt...
# Error processing Part 31.txt: [Errno 22] Invalid argument: "walkthrough_rewrites\\UltraSun_and_UltraMoon\\UltraSun_and_UltraMoon - Part 31 - Tying Loose Ends:Melemele Sea, Seaward Cave, Kala'e Bay, Lake of the MooneUS/ Lake of the SunneUM.txt"
# Keywords for Part 32: Round 2
# Processing Part 32.txt...
# Rewritten walkthrough saved as UltraSun_and_UltraMoon - Part 32 - Round 2.txt
# Finished processing UltraSun_and_UltraMoon
# Processing game: X_and_Y
# Keywords for Part 1: Introduction, Vaniville Town, Route 1, Aquacorde Town, Vaniville Town (Revisited)
# Processing Part 1.txt...
# Rewritten walkthrough saved as X_and_Y - Part 1 - Introduction, Vaniville Town, Route 1, Aquacorde Town, Vaniville Town (Revisited).txt
# Keywords for Part 2: Route 2, Santalune Forest, Route 3, Santalune City, Santalune Gym, Route 4
# Processing Part 2.txt...
# Rewritten walkthrough saved as X_and_Y - Part 2 - Route 2, Santalune Forest, Route 3, Santalune City, Santalune Gym, Route 4.txt
# Keywords for Part 3: Lumiose City (South), Route 5, Camphrier Town
# Processing Part 3.txt...
# Rewritten walkthrough saved as X_and_Y - Part 3 - Lumiose City (South), Route 5, Camphrier Town.txt
# Keywords for Part 4: Route 7 (East), Route 6, Parfum Palace, Route 7 (West), Connecting Cave
# Processing Part 4.txt...
# Rewritten walkthrough saved as X_and_Y - Part 4 - Route 7 (East), Route 6, Parfum Palace, Route 7 (West), Connecting Cave.txt
# Keywords for Part 5: Route 8 (Upper), Ambrette Town, Route 9, Glittering Cave, Route 8 (Lower), Cyllage City, Cyllage Gym
# Processing Part 5.txt...
# Rewritten walkthrough saved as X_and_Y - Part 5 - Route 8 (Upper), Ambrette Town, Route 9, Glittering Cave, Route 8 (Lower), Cyllage City, Cyllage Gym.txt
# Keywords for Part 6: Route 10, Geosenge Town, Route 11, Reflection Cave, Shalour City, Shalour Gym, Tower of Mastery
# Processing Part 6.txt...
# Rewritten walkthrough saved as X_and_Y - Part 6 - Route 10, Geosenge Town, Route 11, Reflection Cave, Shalour City, Shalour Gym, Tower of Mastery.txt
# Keywords for Part 7: Route 12, Azure Bay, Coumarine City, Coumarine Gym, Route 13, Kalos Power Plant
# Processing Part 7.txt...
# Rewritten walkthrough saved as X_and_Y - Part 7 - Route 12, Azure Bay, Coumarine City, Coumarine Gym, Route 13, Kalos Power Plant.txt
# Keywords for Part 8: Lumiose City, Lumiose Gym
# Processing Part 8.txt...
# Rewritten walkthrough saved as X_and_Y - Part 8 - Lumiose City, Lumiose Gym.txt
# Keywords for Part 9: Route 14, Laverre City, Laverre Gym, Poké Ball Factory, Route 15, Lost Hotel, Route 16
# Processing Part 9.txt...
# Rewritten walkthrough saved as X_and_Y - Part 9 - Route 14, Laverre City, Laverre Gym, Poké Ball Factory, Route 15, Lost Hotel, Route 16.txt
# Keywords for Part 10: Dendemille Town, Frost Cavern, Route 17, Anistar City, Anistar Gym
# Processing Part 10.txt...
# Rewritten walkthrough saved as X_and_Y - Part 10 - Dendemille Town, Frost Cavern, Route 17, Anistar City, Anistar Gym.txt
# Keywords for Part 11: Lysandre Labs, Geosenge Town, Team Flare Secret HQ
# Processing Part 11.txt...
# Rewritten walkthrough saved as X_and_Y - Part 11 - Lysandre Labs, Geosenge Town, Team Flare Secret HQ.txt
# Keywords for Part 12: Route 18, Couriway Town, Route 19
# Processing Part 12.txt...
# Rewritten walkthrough saved as X_and_Y - Part 12 - Route 18, Couriway Town, Route 19.txt
# Keywords for Part 13: Snowbelle City, Route 20, Pokémon Village, Snowbelle Gym
# Processing Part 13.txt...
# Rewritten walkthrough saved as X_and_Y - Part 13 - Snowbelle City, Route 20, Pokémon Village, Snowbelle Gym.txt
# Keywords for Part 14: Route 21, Route 22, Victory Road
# Processing Part 14.txt...
# Rewritten walkthrough saved as X_and_Y - Part 14 - Route 21, Route 22, Victory Road.txt
# Keywords for Part 15: The Pokémon League
# Processing Part 15.txt...
# Rewritten walkthrough saved as X_and_Y - Part 15 - The Pokémon League.txt
# Keywords for Part 16: Vaniville Town, Lumiose City, Kiloude City, Friend Safari, Battle Maison, Upgrading the Mega Ring, Looker Bureau
# Processing Part 16.txt...
# Rewritten walkthrough saved as X_and_Y - Part 16 - Vaniville Town, Lumiose City, Kiloude City, Friend Safari, Battle Maison, Upgrading the Mega Ring, Looker Bureau.txt
# Keywords for Part 17: Sea Spirit's Den, Unknown Dungeon, Terminus Cave
# Processing Part 17.txt...
# Rewritten walkthrough saved as X_and_Y - Part 17 - Sea Spirit's Den, Unknown Dungeon, Terminus Cave.txt
# Finished processing X_and_Y
# Processing game: Yellow
# Keywords for Part 1: Introduction, Pallet Town
# Processing Part 1.txt...
# Rewritten walkthrough saved as Yellow - Part 1 - Introduction, Pallet Town.txt
# Keywords for Part 2: Route 1, Viridian City, Pallet Town (revisited), Route 2 (West)
# Processing Part 2.txt...
# Rewritten walkthrough saved as Yellow - Part 2 - Route 1, Viridian City, Pallet Town (revisited), Route 2 (West).txt
# Keywords for Part 3: Viridian Forest, Pewter City, Pewter Gym
# Processing Part 3.txt...
# Rewritten walkthrough saved as Yellow - Part 3 - Viridian Forest, Pewter City, Pewter Gym.txt
# Keywords for Part 4: Route 3, Mt. Moon, Route 4
# Processing Part 4.txt...
# Rewritten walkthrough saved as Yellow - Part 4 - Route 3, Mt. Moon, Route 4.txt
# Keywords for Part 5: Cerulean City, Cerulean Gym, Route 24, Route 25, Route 5, Underground Path (Routes 5-6)
# Processing Part 5.txt...
# Rewritten walkthrough saved as Yellow - Part 5 - Cerulean City, Cerulean Gym, Route 24, Route 25, Route 5, Underground Path (Routes 5-6).txt
# Keywords for Part 6: Route 6, Vermilion City, S.S. Anne, Vermilion Gym
# Processing Part 6.txt...
# Rewritten walkthrough saved as Yellow - Part 6 - Route 6, Vermilion City, S.S. Anne, Vermilion Gym.txt
# Keywords for Part 7: Route 11, Diglett's Cave, Route 2 (East), Pewter Museum of Science, Route 9, Route 10 (North)
# Processing Part 7.txt...
# Rewritten walkthrough saved as Yellow - Part 7 - Route 11, Diglett's Cave, Route 2 (East), Pewter Museum of Science, Route 9, Route 10 (North).txt
# Keywords for Part 8: Rock Tunnel, Route 10 (South), Lavender Town, Route 8, Underground Path (Routes 7-8), Route 7
# Processing Part 8.txt...
# Rewritten walkthrough saved as Yellow - Part 8 - Rock Tunnel, Route 10 (South), Lavender Town, Route 8, Underground Path (Routes 7-8), Route 7.txt
# Keywords for Part 9: Celadon City, Celadon Gym, Rocket Hideout, Pokémon Tower
# Processing Part 9.txt...
# Rewritten walkthrough saved as Yellow - Part 9 - Celadon City, Celadon Gym, Rocket Hideout, Pokémon Tower.txt
# Keywords for Part 10: Saffron City, Silph Co., Saffron Gym
# Processing Part 10.txt...
# Rewritten walkthrough saved as Yellow - Part 10 - Saffron City, Silph Co., Saffron Gym.txt
# Keywords for Part 11: Route 16, Route 17, Route 18, Fuchsia City, Fuchsia Gym, Safari Zone
# Processing Part 11.txt...
# Rewritten walkthrough saved as Yellow - Part 11 - Route 16, Route 17, Route 18, Fuchsia City, Fuchsia Gym, Safari Zone.txt
# Keywords for Part 12: Route 12, Route 13, Route 14, Route 15, Route 19, Route 20 (East), Seafoam Islands, Route 20 (West)
# Processing Part 12.txt...
# Rewritten walkthrough saved as Yellow - Part 12 - Route 12, Route 13, Route 14, Route 15, Route 19, Route 20 (East), Seafoam Islands, Route 20 (West).txt
# Keywords for Part 13: Cinnabar Island, Pokémon Lab, Pokémon Mansion, Cinnabar Gym, Route 21
# Processing Part 13.txt...
# Rewritten walkthrough saved as Yellow - Part 13 - Cinnabar Island, Pokémon Lab, Pokémon Mansion, Cinnabar Gym, Route 21.txt
# Keywords for Part 14: Power Plant, Viridian Gym
# Processing Part 14.txt...
# Rewritten walkthrough saved as Yellow - Part 14 - Power Plant, Viridian Gym.txt
# Keywords for Part 15: Route 22, Route 23, Victory Road
# Processing Part 15.txt...
# Rewritten walkthrough saved as Yellow - Part 15 - Route 22, Route 23, Victory Road.txt
# Keywords for Part 16: Indigo Plateau
# Processing Part 16.txt...
# Rewritten walkthrough saved as Yellow - Part 16 - Indigo Plateau.txt
# Keywords for Part 17: Cerulean Cave
# Processing Part 17.txt...
# Rewritten walkthrough saved as Yellow - Part 17 - Cerulean Cave.txt
# Finished processing Yellow

# %%
import os
from typing import List, Dict
from langchain_community.document_loaders import TextLoader
from langchain.text_splitter import CharacterTextSplitter
from langchain_community.vectorstores import FAISS
from langchain_openai import OpenAIEmbeddings
from langchain.chains import RetrievalQA
from langchain_openai import ChatOpenAI
from dotenv import load_dotenv

load_dotenv()

def load_and_embed_walkthroughs(walkthrough_dir: str = "walkthroughs") -> FAISS:
    documents = []
    for game_folder in os.listdir(walkthrough_dir):
        game_path = os.path.join(walkthrough_dir, game_folder)
        if os.path.isdir(game_path):
            for file_name in os.listdir(game_path):
                file_path = os.path.join(game_path, file_name)
                try:
                    loader = TextLoader(file_path, encoding='utf-8')
                    documents.extend(loader.load())
                except UnicodeDecodeError:
                    try:
                        loader = TextLoader(file_path, encoding='latin-1')
                        documents.extend(loader.load())
                    except Exception as e:
                        print(f"Error loading {file_path}: {e}")

    text_splitter = CharacterTextSplitter(chunk_size=1000, chunk_overlap=0)
    texts = text_splitter.split_documents(documents)
    
    embeddings = OpenAIEmbeddings()
    vectorstore = FAISS.from_documents(texts, embeddings)
    
    return vectorstore

# This function can be run in a Jupyter notebook to create the vectorstore
# vectorstore = load_and_embed_walkthroughs()
# vectorstore.save_local("path/to/save/vectorstore")

# %%
# pokeapi_tool.py
import requests
from langchain.tools import BaseTool

BASE_URL = "https://pokeapi.co/api/v2/"

class PokeAPITool(BaseTool):
    name = "PokeAPI"
    description = """Use this tool to get information about Pokemon, abilities, moves, items, and more from the PokeAPI.
    Input should be in the format: 'category name_or_id'
    Available categories: pokemon, ability, move, item, type, stat, nature, egg-group, generation, version, location, pokemon-species"""

    def _call(self, query: str) -> str:
        try:
            parts = query.split(maxsplit=1)
            if len(parts) != 2:
                return "Error: Input should be in the format 'category name_or_id'"
            
            category, name_or_id = parts
            category = category.lower()
            name_or_id = name_or_id.lower()

            valid_categories = [
                "pokemon", "ability", "move", "item", "type", "stat", 
                "nature", "egg-group", "generation", "version", "location",
                "pokemon-species"
            ]

            if category not in valid_categories:
                return f"Error: Invalid category. Valid categories are: {', '.join(valid_categories)}"

            response = requests.get(f"{BASE_URL}{category}/{name_or_id}")
            if response.status_code != 200:
                return f"Error: Could not find {name_or_id} in {category}"

            data = response.json()
            
            if category == "pokemon":
                return f"""Name: {data['name']}
                Height: {data['height']}
                Weight: {data['weight']}
                Types: {', '.join([t['type']['name'] for t in data['types']])}
                Abilities: {', '.join([a['ability']['name'] for a in data['abilities']])}
                Base Experience: {data['base_experience']}"""
            elif category == "ability":
                effect = next((e['effect'] for e in data['effect_entries'] if e['language']['name'] == 'en'), "No English description available")
                return f"""Name: {data['name']}
                Effect: {effect}
                Pokemon with this ability: {', '.join([p['pokemon']['name'] for p in data['pokemon']][:5])}"""
            elif category == "move":
                effect = next((e['effect'] for e in data['effect_entries'] if e['language']['name'] == 'en'), "No English description available")
                return f"""Name: {data['name']}
                Type: {data['type']['name']}
                Power: {data['power']}
                Accuracy: {data['accuracy']}
                PP: {data['pp']}
                Effect: {effect}"""
            elif category == "item":
                effect = next((e['effect'] for e in data['effect_entries'] if e['language']['name'] == 'en'), "No English description available")
                return f"""Name: {data['name']}
                Category: {data['category']['name']}
                Effect: {effect}"""
            elif category == "type":
                return f"""Name: {data['name']}
                Double damage to: {', '.join([t['name'] for t in data['damage_relations']['double_damage_to']])}
                Half damage from: {', '.join([t['name'] for t in data['damage_relations']['half_damage_from']])}"""
            elif category == "pokemon-species":
                return f"""Name: {data['name']}
                Generation: {data['generation']['name']}
                Capture rate: {data['capture_rate']}
                Base happiness: {data['base_happiness']}
                Growth rate: {data['growth_rate']['name']}"""
            else:
                return f"Basic info for {category} {name_or_id}: {data}"

        except Exception as e:
            return f"Error: {str(e)}"

    def _arun(self, query: str) -> str:
        # This tool does not support async operations
        raise NotImplementedError("This tool does not support async operations")

# %%
# agent_setup.py
from langchain_openai import ChatOpenAI
from langchain.agents import initialize_agent, AgentType
from langchain.memory import ConversationBufferMemory
from pokeapi_tool import PokeAPITool
from dotenv import load_dotenv
import os

load_dotenv()

# Initialize the language model
llm = ChatOpenAI(
    temperature=0,
    model_name="gpt-3.5-turbo",
    openai_api_key=os.getenv("OPENAI_API_KEY")
)

# Initialize the PokeAPI tool
pokeapi_tool = PokeAPITool()

# Initialize conversation memory
memory = ConversationBufferMemory(memory_key="chat_history", return_messages=True)

# Initialize the agent
agent = initialize_agent(
    tools=[pokeapi_tool],
    llm=llm,
    agent=AgentType.CHAT_CONVERSATIONAL_REACT_DESCRIPTION,
    memory=memory,
    verbose=True
)

# Add a system message to give the agent some context
system_message = """You are a helpful Pokemon expert assistant. You can use the PokeAPI tool to retrieve information about Pokemon, abilities, moves, items, types, and more. Always strive to provide accurate and helpful information to the user's questions about Pokemon. If you need specific data, use the PokeAPI tool with the appropriate category and name/id. For example, to get information about Pikachu, you would use the tool with input 'pokemon pikachu'."""

agent.agent.llm_chain.prompt.messages[0].content += system_message
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 5
#       3 from langchain.agents import initialize_agent, AgentType
#       4 from langchain.memory import ConversationBufferMemory
# ----> 5 from pokeapi_tool import PokeAPITool
#       6 from dotenv import load_dotenv
#       7 import os
#
# ModuleNotFoundError: No module named 'pokeapi_tool'

# %%
# main.py
from agent_setup import agent

def answer_pokemon_question(question):
    response = agent.run(input=question)
    return response

if __name__ == "__main__":
    print("Welcome to the Pokemon Assistant! Ask me anything about Pokemon.")
    print("Type 'quit' to exit.")
    
    while True:
        user_question = input("\nYour question: ")
        if user_question.lower() == 'quit':
            print("Thank you for using the Pokemon Assistant. Goodbye!")
            break
        
        answer = answer_pokemon_question(user_question)
        print(f"\nAssistant: {answer}")
